# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Uniform-Distribution" data-toc-modified-id="Uniform-Distribution-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Uniform Distribution</a></span></li><li><span><a href="#Normal-Distribution" data-toc-modified-id="Normal-Distribution-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Normal Distribution</a></span></li><li><span><a href="#Bernoulli-Distribution" data-toc-modified-id="Bernoulli-Distribution-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Bernoulli Distribution</a></span></li><li><span><a href="#Binomial-Distribution" data-toc-modified-id="Binomial-Distribution-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Binomial Distribution</a></span></li><li><span><a href="#Poisson-Distribution" data-toc-modified-id="Poisson-Distribution-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Poisson Distribution</a></span></li><li><span><a href="#Beta-Distribution" data-toc-modified-id="Beta-Distribution-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Beta Distribution</a></span></li><li><span><a href="#Gamma-Distribution" data-toc-modified-id="Gamma-Distribution-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Gamma Distribution</a></span></li><li><span><a href="#Log-Normal-Distribution" data-toc-modified-id="Log-Normal-Distribution-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Log Normal Distribution</a></span></li><li><span><a href="#Negative-Binomial-Distribution" data-toc-modified-id="Negative-Binomial-Distribution-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Negative Binomial Distribution</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10, 8]
plt.style.use('fivethirtyeight')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import scipy
import scipy.stats as stats

# versions
import watermark
# %load_ext watermark
# %watermark -a "Bhishan Poudel" -d -v -m
print()
# %watermark -iv
# Out:
# Bhishan Poudel 2021-03-09
#
# CPython 3.7.7
# IPython 7.19.0
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
#
# seaborn   0.11.0
# numpy     1.19.5
# scipy     1.4.1
# pandas    1.1.4
# watermark 2.0.2

# %% [markdown]
# # Uniform Distribution

# %%
# random numbers from uniform distribution
# Generate 10 numbers from 0 to 10
n = 10000
a = 0
b = 10
data_uniform = stats.uniform.rvs(size=n, loc = a, scale=b)

ax = sns.displot(data_uniform,
                  bins=100,
                  kde=False,
                  color='skyblue',
                  )
ax.set(xlabel='Uniform ', ylabel='Frequency')

# %% [markdown]
# # Normal Distribution

# %%
# generate random numbersfrom N(0,1)
data_normal = stats.norm.rvs(size=10000,loc=0,scale=1)
ax = sns.displot(data_normal,
                  bins=100,
                  kde=False,
                  color='skyblue',
                  )
ax.set(xlabel='Normal', ylabel='Frequency')

# %% [markdown]
# # Bernoulli Distribution

# %%
# generate bernoulli
data_bern = stats.bernoulli.rvs(size=10000,p=0.3)
ax= sns.displot(data_bern,
                 kde=False,
                 color="skyblue",
                 )
ax.set(xlabel='Bernoulli', ylabel='Frequency')

# %% [markdown]
# # Binomial Distribution

# %%
n = 1 # 1 gives 0 and 1
n = 2
data_binom = stats.binom.rvs(n=n,p=0.5,size=10000)
ax = sns.displot(data_binom,
                  kde=False,
                  color='skyblue',
                  )
ax.set(xlabel='Binomial', ylabel='Frequency')

# %%
pd.Series(data_binom).value_counts()
# Out:
# 1    5027
# 0    2506
# 2    2467
# dtype: int64

# %%
np.bincount(data_binom)
# Out:
# array([2506, 5027, 2467])

# %%
np.count_nonzero(data_binom)
# Out:
# 7494

# %%
[i for i in dir(np) if 'count' in i]
# Out:
# ['bincount', 'busday_count', 'count_nonzero']

# %% [markdown]
# # Poisson Distribution
# Poisson random variable is typically used to model the number of times an event happened in a time interval. For example, number of users visited your website in an interval can be thought of a Poisson process. Poisson distribution is described in terms of the rate (mu) at which the events happen. We can generate Poisson random variables in Python using poisson.rvs.

# %%
data_poisson = stats.poisson.rvs(mu=3, size=10000)
ax = sns.displot(data_poisson,
                  kde=False,
                  color='green',
                  )
ax.set(xlabel='Poisson', ylabel='Frequency')

# %% [markdown]
# # Beta Distribution
# We can understand Beta distribution as a distribution for probabilities. Beta distribution is a continuous distribution taking values from 0 to 1. It is defined by two parameters alpha and beta, depending on the values of alpha and beta they can assume very different distributions.

# %%
data_beta = stats.beta.rvs(1, 1, size=10000)
ax = sns.displot(data_beta,
                  kde=False,
                  bins=100,
                  color='skyblue',
                  )
ax.set(xlabel='Beta(1,1)', ylabel='Frequency')

# %%
data_beta_a10b1 = stats.beta.rvs(10, 1, size=10000)
sns.displot(data_beta_a10b1,
             kde=False,
             bins=50,
             color='skyblue',
             )
ax.set(xlabel='Beta(10,1)', ylabel='Frequency')

# %%
data_beta_a1b10 = stats.beta.rvs(1, 10, size=10000)
ax = sns.displot(data_beta_a1b10,
                kde=False,
                bins=100,
                color='skyblue',
                )
ax.set(xlabel='Beta(1,10)', ylabel='Frequency')

# %%
data_beta_a10b10 = stats.beta.rvs(10, 10, size=10000)
ax = sns.displot(data_beta_a10b10,
                  kde=False,
                  bins=100,
                  color='skyblue',
                  )
ax.set(xlabel='Beta(10,10)', ylabel='Frequency')

# %% [markdown]
# # Gamma Distribution

# %%
data_gamma = stats.gamma.rvs(a=5, size=10000)
ax = sns.displot(data_gamma,
                  kde=False,
                  bins=100,
                  color='skyblue',
                  )
ax.set(xlabel='Gamma', ylabel='Frequency')

# %% [markdown]
# # Log Normal Distribution

# %%
data_lognorm = stats.lognorm.rvs(0.2, size=10000)
ax = sns.displot(data_lognorm,kde=False,
                  bins=100,
                  color='skyblue',
                  )
ax.set(xlabel='Log Normal', ylabel='Frequency')

# %% [markdown]
# # Negative Binomial Distribution
# Negative Binomial Distribution is another random variable with discrete outcome and as the name suggests it is related to binomial/bernoulli distribution.

# %%
data_nbinom = stats.nbinom.rvs(10, 0.5, size=10000)
ax = sns.displot(data_nbinom,
                  kde=False,
                  color='skyblue',
                  )
ax.set(xlabel='Negative Binomial', ylabel='Frequency')
